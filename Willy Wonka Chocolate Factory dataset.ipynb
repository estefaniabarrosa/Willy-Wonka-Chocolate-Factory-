# %% [markdown]
# # Willy Wonka Chocolate Factory dataset.
#
# ##  Project Goal
#
# The goal of this project is to analyze the Willy Wonka Chocolate Factory dataset in order to identify key patterns in product performance and regional demand.
#
# By leveraging SQL and Python, we aim to support business decision-making by answering questions such as:
#
# - Which chocolate products perform best?
# - Which regions represent the strongest opportunities?
# - What factors influence product success?
#
# The final objective is to provide actionable insights that help optimize production, improve resource allocation, and support strategic growth within the factory.

# %%
import pandas as pd

df = pd.read_csv("wonka_choc_factory.csv")

df.head()
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10194 non-null  int64
#  1   Order Date      10194 non-null  str
#  2   Ship Date       10194 non-null  str
#  3   Ship Mode       10194 non-null  str
#  4   Customer ID     10194 non-null  int64
#  5   Country/Region  10194 non-null  str
#  6   City            10194 non-null  str
#  7   State/Province  10194 non-null  str
#  8   Postal Code     10194 non-null  str
#  9   Division        10194 non-null  str
#  10  Region          10194 non-null  str
#  11  Product Name    10194 non-null  str
#  12  Sales           10194 non-null  float64
#  13  Units           10194 non-null  int64
#  14  Gross Profit    10194 non-null  float64
#  15  Cost            10194 non-null  float64
#  16  Factory         10194 non-null  str
#  17  Latitude        10194 non-null  float64
# ...

# %% [markdown]
# ## Key Analytical Questions
#
# - What does each row represent? (a sale, a product, a factory…)
# - What columns do we have?
# - What seems important?
#      - price
#      - product
#      - category
#      - region
#      - sales / production / stock
#
# ## Business Problem:
#
# Willy Wonka Chocolate Factory needs to understand which products and regions are performing best in order to optimize production and maximize profitability.
#
# ## Reserch Questions:
#
# - RQ1: Which chocolate products generate the highest sales or demand?
#
# - RQ2: Which regions or markets perform better and which require attention?
#
# - RQ3: Are there product characteristics (price, category, ingredients, rating) that influence performance?

# %%
df = df.drop(columns=["Unnamed: 0"]) # This column appears to be an index and will be removed.

# %%
# Order Date and Ship Date are str
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %% [markdown]
# ## Initial Observations
#
# - Each row represents a transaction (sale)
# - The dataset includes sales, cost and profit metrics
# - Geographic information is available (country, region, city)
# - Product-level analysis is possible
# - Time-based analysis is possible (order date)

# %% [markdown]
# ## Hypotheses
#
# - H1: Premium chocolate products with higher unit prices generate disproportionately higher profit margins despite lower sales volume.
# - H2: Certain regions exhibit consistently higher profitability due to purchasing behavior rather than transaction volume alone.
# - H3: Products with lower production cost-to-price ratios contribute more effectively to long-term profitability.
